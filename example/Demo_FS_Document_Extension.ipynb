# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Document
from ndi.database import FileSystem as Database
from test_app.subject_doc import Subject

# %%
db = Database('../test_exp', document_extensions=[Subject])

# %%
db._document_collections
# Out:
# {'Subject': test_app.subject_doc.Subject}

# %%
db._collections
# Out:
# {ndi.experiment.Experiment: <ndi.database.file_system.Collection at 0x11c655f70>,
#  ndi.daq_system.DaqSystem: <ndi.database.file_system.Collection at 0x10ca07fa0>,
#  ndi.probe.Probe: <ndi.database.file_system.Collection at 0x10bc60640>,
#  ndi.epoch.Epoch: <ndi.database.file_system.Collection at 0x10bcbe0a0>,
#  ndi.channel.Channel: <ndi.database.file_system.Collection at 0x10bc11f70>,
#  ndi.document.Document: <ndi.database.file_system.Collection at 0x10bc11fa0>,
#  test_app.subject_doc.Subject: <ndi.database.file_system.Collection at 0x11c655b20>,
#  'document_lookup': <ndi.database.file_system.DocumentLookupCollection at 0x11c655e20>}

# %%
subject = Subject('reference','species', 'strain', 'variant')

# %%
doc = Document('subject', subject, experiment_id='', file_id='', parent_id='')

# %%
doc.document_extension

# %%
doc.document_type
# Out:
# 'Subject'

# %%
db.add(doc)

# %%
db.find(Subject)

# %%
result = db.find_by_id(Document, doc.id)

# %%
doc_ext = result.document_extension

# %%
print(doc_ext.reference)
print(doc_ext.species)
print(doc_ext.strain)
print(doc_ext.variant)
# Out:
# reference
# species
# strain
# variant
