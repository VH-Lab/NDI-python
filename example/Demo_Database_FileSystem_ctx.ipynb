# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Experiment, DaqSystem, FileNavigator
from ndi.daqreaders import MockReader
from ndi.database import FileSystem as Database, Query as Q

# %%
db = Database('../test_exp')

# %%
fn = FileNavigator(epoch_file_patterns=['.*\\.wav', '.*\\.txt'], 
                   metadata_file_pattern='.*\\.txt')

# %%
ds = DaqSystem(name='myDaq1',
              file_navigator=fn,
              daq_reader=MockReader)
ds2 = DaqSystem(name='myDaq2',
               file_navigator=fn,
               daq_reader=MockReader)

# %%
e = Experiment(name='myExperiment3', 
               daq_systems=[ds, ds2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-4606e04b1841> in <module>
# ----> 1 e = Experiment(name='myExperiment3',
#       2                daq_systems=[ds, ds2])
#
# ~/projects/ndi/ndi-python/ndi/experiment.py in __init__(self, name, daq_systems, id_)
#      33         self.daq_systems: T.List[T.DaqSystem] = []
#      34         for daq_system in daq_systems:
# ---> 35             self.add_daq_system(daq_system)
#      36
#      37     # Flatbuffer Methods
#
# ~/projects/ndi/ndi-python/ndi/experiment.py in add_daq_system(self, daq_system)
#     100         # NOTE: we should use daq_system_ids instead of the ndi_objects
#     101         self.daq_systems.append(daq_system)
# --> 102         self.ctx.add(daq_system)
#     103
#     104     def add_related_obj_to_db(self, obj: T.NdiObjectWithExperimentId) -> None:
#
# AttributeError: 'Experiment' object has no attribute 'ctx'

# %%
db.add_experiment(e)

# %%
e.ctx

# %%
e2 = db.find_by_id(Experiment, e.id)

# %%
e2.ctx

# %%
e2 == e

# %%
e2 == db.find(Experiment,Q('name') == 'myExperiment3')[0]

# %%
db.find(Experiment, Q('name') == 'myExperiment2')

# %%
ds_results = db.find(DaqSystem, Q('experiment_id') == e.id)

# %%
print(ds_results)

# %%
e.daq_systems[0] == ds_results[0]

# %%
db.find(Experiment)

# %%
db.delete_by_id(Experiment, e.id)

# %%
try:
    db.find_by_id(Experiment, e.id)
except FileNotFoundError:
    print('File not found')

# %%
db.delete_many(Experiment)

# %%
db.find(Experiment)

# %%
try:
    db.add(ds)
except FileExistsError as e:
    print(e)

# %%
db.upsert(ds)

# %%
print(ds.name)

# %%
db.update_by_id(DaqSystem, ds.id, { 'name': 'daq2' })

# %%
ds2 = db.find_by_id(DaqSystem, ds.id)

# %%
print(ds2.name)

# %%
try:
    db.add('a')
except TypeError as e:
    print(e)

# %%
db.drop_collection(Experiment)
try:
    db.find(Experiment)
except KeyError as e:
    print(e)
