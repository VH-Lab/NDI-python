# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Document
from ndi.database import FileSystem as Database
from ndi.database.utils import print_everything_in, destroy_everything_in

# %%
# Connecting to database
db = Database('../test_exp')
destroy_everything_in(db)

# %%
# Creating a dummy document
doc = Document(data={'hello': 'world'}, type_='test_doc', name='og', experiment_id='1234')

# Adding document to database
db.add(doc)

# %%
# Creating new document
force = Document({ 'F' : 'ma'}, 'force', 'equation', '1234')

# Adding force document as a dependency of the above document (doc)
doc.add_dependency(force)

# %%
# Creating new document
gas = Document({ 'PV': 'nRT' }, 'gas', 'equation', '1234')

# Adding gas document as a dependency of the above document (force)
force.add_dependency(gas)

# %%
# Checking document id
doc.id
# Out:
# 'cc0600017f4e413d933ef3d01f66a895'

# %%
# Checking document data
doc.data
# Out:
# {'_metadata': {'name': 'og',
#   'type': 'test_doc',
#   'experiment_id': '1234',
#   'parent_id': '',
#   'asc_path': '',
#   'version_depth': 0,
#   'latest_version': True},
#  '_dependencies': {'force': '7edb3bddc7b149ec995f8530ff39f072'},
#  '_depends_on': [],
#  'hello': 'world'}

# %%
# Finding a specific document by find_by_id search
result = db.find_by_id(doc.id)

# %%
# Showing data (with dependencies)
result.data
# Out:
# {'_metadata': {'name': 'og',
#   'type': 'test_doc',
#   'experiment_id': '1234',
#   'parent_id': '',
#   'asc_path': '',
#   'version_depth': 0,
#   'latest_version': True},
#  '_dependencies': {'force': '80ab2c2d902d4b8eb395c442d698c58d'},
#  '_depends_on': [],
#  'hello': 'world'}

# %%
# Returning dictionary of dependencies for a document and converting dependency ids to document objects
result.get_dependencies()
# Out:
# {'force': <ndi.document.Document at 0x11101e940>}

# %%
result.data
# Out:
# {'_metadata': {'name': 'og',
#   'type': 'test_doc',
#   'experiment_id': '1234',
#   'parent_id': '',
#   'asc_path': '',
#   'version_depth': 0,
#   'latest_version': True},
#  '_dependencies': {'force': <ndi.document.Document at 0x11101e940>},
#  '_depends_on': [],
#  'hello': 'world'}

# %%
# Viewing dependency data
result.data['_dependencies']['force'].data
# Out:
# {'_metadata': {'name': 'force',
#   'type': 'equation',
#   'experiment_id': '1234',
#   'parent_id': '',
#   'asc_path': '',
#   'version_depth': 0,
#   'latest_version': True},
#  '_dependencies': {'gas': 'ff15799434fa4d55a286a841ff2e81d0'},
#  '_depends_on': ['cc0600017f4e413d933ef3d01f66a895'],
#  'F': 'ma'}

# %%
# Nesting deeper to show that dependencies are still document objects
result.data['_dependencies']['force'].get_dependencies()
# Out:
# {'gas': <ndi.document.Document at 0x104e43c10>}

# %%
# Viewing data of dependency of dependency
result.data['_dependencies']['force'].data['_dependencies']['gas'].data
# Out:
# {'_metadata': {'name': 'gas',
#   'type': 'equation',
#   'experiment_id': '1234',
#   'parent_id': '',
#   'asc_path': '',
#   'version_depth': 0,
#   'latest_version': True},
#  '_dependencies': {},
#  '_depends_on': ['80ab2c2d902d4b8eb395c442d698c58d'],
#  'PV': 'nRT'}

# %%
# Finding all Document objects in database
db.find()
# Out:
# [<ndi.document.Document at 0x104e43490>,
#  <ndi.document.Document at 0x1110402e0>,
#  <ndi.document.Document at 0x111040640>]

# %%
# Delete force document using its id
db.delete_by_id(force.id, force=True)

# %%
# Showing that a document was deleted
for result in db.find():
    print(result.data)
# Out:
# {'_metadata': {'name': 'gas', 'type': 'equation', 'experiment_id': '1234', 'parent_id': '', 'asc_path': '', 'version_depth': 0, 'latest_version': True}, '_dependencies': {}, '_depends_on': ['80ab2c2d902d4b8eb395c442d698c58d'], 'PV': 'nRT'}
# {'_metadata': {'name': 'og', 'type': 'test_doc', 'experiment_id': '1234', 'parent_id': '', 'asc_path': '', 'version_depth': 0, 'latest_version': True}, '_dependencies': {'force': '80ab2c2d902d4b8eb395c442d698c58d'}, '_depends_on': [], 'hello': 'world'}
