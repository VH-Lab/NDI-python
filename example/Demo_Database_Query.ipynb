# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi.database import Query as Q

# %%
# a = Q('a').equals('apple')
a = Q('a') == 'apple'
print(a)
# print(a.query)
print(a())
# Out:
# <Query ('a', '==', 'apple')>
# ('a', '==', 'apple')

# %%
# a = Q('b').not_equals('bee')
b = Q('b') != 'bee'
print(b)
print(b())
# Out:
# <Query ('b', '!=', 'bee')>
# ('b', '!=', 'bee')

# %%
# z = a.and_(b)
# z = Q('a').equals('apple').and_(Q('b').not_equals('bee'))
# z = Q('a').equals('apple') & Q('b').not_equals('bee')
z = a & b
print(isinstance(z, Q))
print(z)
for query in z:
    print(query)
# Out:
# True
# <AndQuery [<Query ('a', '==', 'apple')>, <Query ('b', '!=', 'bee')>]>
# <Query ('a', '==', 'apple')>
# <Query ('b', '!=', 'bee')>

# %%
# y = a.or_(b)
# y = Q('a').equals('apple').or_(Q('b').not_equals('bee'))
# y = Q('a').equals('apple') | Q('b').not_equals('bee')
y = a | b
print(isinstance(y, Q))
print(y)
for query in y:
    print(query)
# Out:
# True
# <OrQuery [<Query ('a', '==', 'apple')>, <Query ('b', '!=', 'bee')>]>
# <Query ('a', '==', 'apple')>
# <Query ('b', '!=', 'bee')>

# %%
# c = Q('c').greater_than_or_equal_to(5)
c = Q('c') >= 5
print(c)
print(c())
# Out:
# <Query ('c', '>=', 5)>
# ('c', '>=', 5)

# %%
# d = Q('d').less_than(5)
d = Q('d') < 5
print(d)
print(d())
# Out:
# <Query ('d', '<', 5)>
# ('d', '<', 5)

# %%
# (a.or_(b)).and_((c.or_(d)))
for query in ((a | b) & ( c | d)):
    print(query)
# Out:
# <OrQuery [<Query ('a', '==', 'apple')>, <Query ('b', '!=', 'bee')>]>
# <OrQuery [<Query ('c', '>=', 5)>, <Query ('d', '<', 5)>]>

# %%
# (a.and_(b)).or_(c.and_(d))
for query in ((a & b) | (c & d)):
    print(query)
# Out:
# <AndQuery [<Query ('a', '==', 'apple')>, <Query ('b', '!=', 'bee')>]>
# <AndQuery [<Query ('c', '>=', 5)>, <Query ('d', '<', 5)>]>

# %%
x = ((a & b) & c)
print(x)
for query in x:
    print(query)
# Out:
# <AndQuery [<Query ('a', '==', 'apple')>, <Query ('b', '!=', 'bee')>, <Query ('c', '>=', 5)>]>
# <Query ('a', '==', 'apple')>
# <Query ('b', '!=', 'bee')>
# <Query ('c', '>=', 5)>

# %%
w = (a | b) | c
print(w)
for query in w:
    print(query)
# Out:
# <OrQuery [<Query ('a', '==', 'apple')>, <Query ('b', '!=', 'bee')>, <Query ('c', '>=', 5)>]>
# <Query ('a', '==', 'apple')>
# <Query ('b', '!=', 'bee')>
# <Query ('c', '>=', 5)>

# %%
e = Q('e').match(r'ele[a-z]$')
print(e)
print(e())
# Out:
# <Query ('e', 'match', 'ele[a-z]$')>
# ('e', 'match', 'ele[a-z]$')

# %%
f = Q('f').contains('fish')
print(f)
print(f())
# Out:
# <Query ('f', 'contains', 'fish')>
# ('f', 'contains', 'fish')

# %%
# g = Q('g').exists()
g = +Q('g')
print(g)
print(g())
# Out:
# <Query ('g', 'exists', True)>
# ('g', 'exists', True)

# %%
# h = Q('h').exists(False)
h = -Q('h')
print(h)
print(h())
# Out:
# <Query ('h', 'exists', False)>
# ('h', 'exists', False)

# %%
# i = Q('i').in_([1, 2, 3, 4])
i = Q('i') >> [1, 2, 3, 4]
print(i)
print(i())
# Out:
# <Query ('i', 'in', [1, 2, 3, 4])>
# ('i', 'in', [1, 2, 3, 4])

# %%
# Intentional Error
j = Q('j')
print(j)
# Out:
# ---------------------------------------------------------------------------
# QueryUnresolvedError                      Traceback (most recent call last)
# <ipython-input-18-0975b113708e> in <module>
#       1 # Intentional Error
#       2 j = Q('j')
# ----> 3 print(j)
#
# ~/Desktop/Squishymedia-Brandeis/ndi-python/ndi/database/query.py in __repr__(self)
#      55
#      56     def __repr__(self):
# ---> 57         return f'<Query {self()}>'
#      58
#      59     # Methods for combining ndi_queries
#
# ~/Desktop/Squishymedia-Brandeis/ndi-python/ndi/database/query.py in __call__(self)
#      52
#      53     def __call__(self):
# ---> 54         return self.query
#      55
#      56     def __repr__(self):
#
# ~/Desktop/Squishymedia-Brandeis/ndi-python/ndi/database/query.py in query(self)
#      48             return self.__query
#      49         else:
# ---> 50             raise QueryUnresolvedError(
#      51                 f'The query field \'{self.field}\' has not been resolved yet')
#      52
#
# QueryUnresolvedError: The query field 'j' has not been resolved yet
