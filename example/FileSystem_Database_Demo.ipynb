# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Experiment, DaqSystem, FileNavigator
from ndi.daqsystem.daqreaders import MockReader
from ndi.database import FileSystem as Database

# %%
db = Database('../test_exp')

# %%
fn = FileNavigator(epoch_file_patterns=['.*\\.wav', '.*\\.txt'], 
                   metadata_file_pattern='.*\\.txt')

# %%
ds = DaqSystem(name='myDaq1',
              file_navigator=fn,
              daq_reader=MockReader)

# %%
e = Experiment(name='myExperiment3', 
               daqsystems=[ds])

# %%
db.add_experiment(e)

# %%
e2 = db.find_by_id(Experiment, e.id)

# %%
e2 == e
# Out:
# True

# %%
db.find(Experiment, name='myExperiment')
# Out:
# [<ndi.experiment.Experiment at 0x116f77f90>,
#  <ndi.experiment.Experiment at 0x116f7f390>,
#  <ndi.experiment.Experiment at 0x116f7f6d0>,
#  <ndi.experiment.Experiment at 0x116f7f7d0>,
#  <ndi.experiment.Experiment at 0x116f7f790>,
#  <ndi.experiment.Experiment at 0x116f7f290>,
#  <ndi.experiment.Experiment at 0x116f7f0d0>,
#  <ndi.experiment.Experiment at 0x116f7fb10>,
#  <ndi.experiment.Experiment at 0x116f7fb90>]

# %%
db.find(Experiment, name='myExperiment2')
# Out:
# [<ndi.experiment.Experiment at 0x116f7fed0>,
#  <ndi.experiment.Experiment at 0x116f9c0d0>,
#  <ndi.experiment.Experiment at 0x116f9c250>,
#  <ndi.experiment.Experiment at 0x116f9c2d0>,
#  <ndi.experiment.Experiment at 0x116f9c3d0>]

# %%
ds_results = db.find(DaqSystem, experiment_id=e.id)

# %%
e.daqsystems[0] == ds_results[0]
# Out:
# True
