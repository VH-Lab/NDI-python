# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Document
from ndi.database.sql import SQL as Database
from ndi.database.query import Query as Q, AndQuery, OrQuery
from ndi.database.utils import print_everything_in, destroy_everything_in
from sqlalchemy import and_, or_

# %%
db = Database('postgres://postgres:1Password!@localhost:5432/practice')

# %%
gas = Document({ 'PV': 'nRT' })
db.add(gas)

# %%
force = Document({ 'F' : 'ma'})
force.add_dependency({'gas': gas.id })
db.add(force)

# %%
doc = Document({'hello': 'world'})
doc.add_dependency({ 'force': force.id })
db.add(doc)

# %%
doc.id
# Out:
# 'd97c072f6aa74266a211daa26c0956f2'

# %%
doc.data
# Out:
# {'_metadata': {'experiment_id': '',
#   'version_depth': 0,
#   'parent_id': '',
#   'asc_path': ''},
#  '_dependencies': {'force': 'e9f54509e4ac4f1f9768f293861c9929'},
#  'hello': 'world'}

# %%
result = db.find_by_id(doc.id)

# %%
result.data
# Out:
# {'_metadata': {'experiment_id': '',
#   'version_depth': 0,
#   'parent_id': '',
#   'asc_path': ''},
#  '_dependencies': {'force': 'e9f54509e4ac4f1f9768f293861c9929'},
#  'hello': 'world'}

# %%
db.get_dependencies(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-302277a9ca07> in <module>
# ----> 1 db.get_dependencies(result)
#
# AttributeError: 'SQL' object has no attribute 'get_dependencies'

# %%
result.data

# %%
result.data['_dependencies']['force'].data

# %%
db.get_dependencies(result.data['_dependencies']['force'])

# %%
result.data['_dependencies']['force'].data['_dependencies']['gas'].data

# %%
db.find()

# %%
db.delete_by_id(force.id)

# %%
for result in db.find():
    print(result.data)
