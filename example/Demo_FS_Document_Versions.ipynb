# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Document
from ndi.database import FileSystem as Database, Query as Q

# %%
db = Database('../test_exp')

# %%
doc = Document({ 'subject': 'mouse' })
doc.id
# Out:
# '63ab536f35bb4b41bc9f23c4b1beaf71'

# %%
doc.data['_metadata']
# Out:
# {'name': '',
#  'type': '',
#  'experiment_id': '',
#  'parent_id': '',
#  'asc_path': '',
#  'version_depth': 0}

# %%
db.add(doc)

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'name': '', 'type': '', 'experiment_id': '', 'parent_id': '', 'asc_path': '', 'version_depth': 0}, '_dependencies': {}, 'subject': 'mouse'}

# %%
doc.data['subject'] = 'elephant'

# %%
doc.save_updates()

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'name': '', 'type': '', 'experiment_id': '', 'parent_id': '63ab536f35bb4b41bc9f23c4b1beaf71', 'asc_path': ',63ab536f35bb4b41bc9f23c4b1beaf71', 'version_depth': 1}, '_dependencies': {}, 'subject': 'elephant'}

# %%
doc.data['subject'] = 'elephant'
doc.save_updates()

# %%
doc
