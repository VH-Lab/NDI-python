# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Document, Query as Q
from ndi.database import FileSystem as Database

# %%
db = Database('../test_exp')

# %%
doc = Document({ 'subject': 'mouse' })
doc.id
# Out:
# 'a82efe5c7d8e468a941aae73f486ffe2'

# %%
doc.data['_metadata']
# Out:
# {'name': '',
#  'type': '',
#  'experiment_id': '',
#  'parent_id': '',
#  'asc_path': '',
#  'version_depth': 0,
#  'latest_version': True}

# %%
db.add(doc)

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'name': '', 'type': '', 'experiment_id': '', 'parent_id': '', 'asc_path': '', 'version_depth': 0, 'latest_version': True}, '_dependencies': {}, '_depends_on': [], 'subject': 'mouse'}

# %%
doc.data['subject'] = 'elephant'

# %%
doc.save_updates()

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'name': '', 'type': '', 'experiment_id': '', 'parent_id': 'a82efe5c7d8e468a941aae73f486ffe2', 'asc_path': ',a82efe5c7d8e468a941aae73f486ffe2', 'version_depth': 1, 'latest_version': True}, '_dependencies': {}, '_depends_on': [], 'subject': 'elephant'}

# %%
doc.data['subject'] = 'elephants'
doc.save_updates()

# %%
doc.data
# Out:
# {'_metadata': {'name': '',
#   'type': '',
#   'experiment_id': '',
#   'parent_id': '70298f4e1f3044fd849ea40306f5e59a',
#   'asc_path': ',70298f4e1f3044fd849ea40306f5e59a,a82efe5c7d8e468a941aae73f486ffe2',
#   'version_depth': 2,
#   'latest_version': True},
#  '_dependencies': {},
#  '_depends_on': [],
#  'subject': 'elephants'}

# %%
history = doc.get_history()
[d.data for d in history]
# Out:
# [{'_metadata': {'name': '',
#    'type': '',
#    'experiment_id': '',
#    'parent_id': '',
#    'asc_path': '',
#    'version_depth': 0,
#    'latest_version': False},
#   '_dependencies': {},
#   '_depends_on': [],
#   'subject': 'elephant'},
#  {'_metadata': {'name': '',
#    'type': '',
#    'experiment_id': '',
#    'parent_id': 'a82efe5c7d8e468a941aae73f486ffe2',
#    'asc_path': ',a82efe5c7d8e468a941aae73f486ffe2',
#    'version_depth': 1,
#    'latest_version': False},
#   '_dependencies': {},
#   '_depends_on': [],
#   'subject': 'elephants'}]

# %%
# Should throw warning
# try:
#     doc.delete_self()
# except RuntimeWarning(e):
#     pass

# %%
doc.delete_self(force=True, remove_history=True)
# Out:
# <ndi.document.Document object at 0x116dbe0d0>
# <ndi.document.Document object at 0x116da6610>

# %%
db.find_by_id(doc.id)

# %%
db.find_by_id(history[-1].id)
