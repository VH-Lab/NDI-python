# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Document
from ndi.database import FileSystem as Database, Query as Q

# %%
db = Database('../test_exp')

# %%
doc = Document({ 'subject': 'mouse' })

# %%
doc.data['_metadata']
# Out:
# {'experiment_id': '', 'version_depth': 0, 'parent_id': '', 'asc_path': ''}

# %%
db.add(doc)

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'experiment_id': '', 'version_depth': 0, 'parent_id': '', 'asc_path': ''}, '_dependencies': {}, 'subject': 'mouse'}

# %%
doc.data['subject'] = 'elephant'

# %%
db.update(doc)

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'experiment_id': '', 'version_depth': 1, 'parent_id': '0879bd962b8d4b47921bac8800f3997c', 'asc_path': ',0879bd962b8d4b47921bac8800f3997c'}, '_dependencies': {}, 'subject': 'elephant'}
