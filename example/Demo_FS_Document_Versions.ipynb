# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Document
from ndi.database import FileSystem as Database, Query as Q

# %%
db = Database('../test_exp')

# %%
doc = Document({ 'subject': 'mouse' })
doc.id
# Out:
# '58d0fefdb17440a9b0514cec915b772b'

# %%
doc.data['_metadata']
# Out:
# {'name': '',
#  'type': '',
#  'experiment_id': '',
#  'parent_id': '',
#  'asc_path': '',
#  'version_depth': 0,
#  'latest_version': True}

# %%
db.add(doc)

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'name': '', 'type': '', 'experiment_id': '', 'parent_id': '', 'asc_path': '', 'version_depth': 0, 'latest_version': True}, '_dependencies': {}, 'subject': 'mouse'}

# %%
doc.data['subject'] = 'elephant'

# %%
doc.save_updates()

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'name': '', 'type': '', 'experiment_id': '', 'parent_id': '58d0fefdb17440a9b0514cec915b772b', 'asc_path': ',58d0fefdb17440a9b0514cec915b772b', 'version_depth': 1, 'latest_version': True}, '_dependencies': {}, 'subject': 'elephant'}

# %%
doc.data['subject'] = 'elephants'
doc.save_updates()

# %%
doc.data
# Out:
# {'_metadata': {'name': '',
#   'type': '',
#   'experiment_id': '',
#   'parent_id': '6aed0da1f5f8428583c5727e192bd2d8',
#   'asc_path': ',6aed0da1f5f8428583c5727e192bd2d8,58d0fefdb17440a9b0514cec915b772b',
#   'version_depth': 2,
#   'latest_version': True},
#  '_dependencies': {},
#  'subject': 'elephants'}

# %%
history = doc.get_history()
[d.data for d in history]
# Out:
# [{'_metadata': {'name': '',
#    'type': '',
#    'experiment_id': '',
#    'parent_id': '',
#    'asc_path': '',
#    'version_depth': 0,
#    'latest_version': False},
#   '_dependencies': {},
#   'subject': 'elephant'},
#  {'_metadata': {'name': '',
#    'type': '',
#    'experiment_id': '',
#    'parent_id': '58d0fefdb17440a9b0514cec915b772b',
#    'asc_path': ',58d0fefdb17440a9b0514cec915b772b',
#    'version_depth': 1,
#    'latest_version': False},
#   '_dependencies': {},
#   'subject': 'elephants'}]

# %%
doc.delete()
# Out:
# ------------------------------------------------------------------------
# RuntimeWarning                         Traceback (most recent call last)
# <ipython-input-14-d1d4cf99cfdf> in <module>
# ----> 1 doc.delete()
#
# ~/projects/ndi/ndi-python/ndi/document.py in delete(self, force, remove_history)
#     149                 self.ctx.delete(ndi_document)
#     150         else:
# --> 151             raise RuntimeWarning('Are you sure you want to delete this document? This will permanently remove it and its dependencies. To delete anyway, use the force argument: db.update(document, force=True). To clear the version history of this document and related dependencies, use the remove_history argument.')
#
# RuntimeWarning: Are you sure you want to delete this document? This will permanently remove it and its dependencies. To delete anyway, use the force argument: db.update(document, force=True). To clear the version history of this document and related dependencies, use the remove_history argument.

# %%
doc.delete(force=True, remove_history=True)

# %%
db.find_by_id(doc.id)
# TODO: we should have this return None when the file is not found
# Out:
# ------------------------------------------------------------------------
# FileNotFoundError                      Traceback (most recent call last)
# <ipython-input-16-29adccda11a9> in <module>
# ----> 1 db.find_by_id(doc.id)
#       2 # TODO: we should have this return None when the file is not found
#
# ~/projects/ndi/ndi-python/ndi/database/file_system.py in find_by_id(self, id_)
#      78
#      79     def find_by_id(self, id_):
# ---> 80         doc = Document.from_flatbuffer((self.db_dir / f'{id_}.dat').read_bytes())
#      81         return doc.with_ctx(self)
#      82
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pathlib.py in read_bytes(self)
#    1220         Open the file in bytes mode, read it, and close the file.
#    1221         """
# -> 1222         with self.open(mode='rb') as f:
#    1223             return f.read()
#    1224
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1213         if self._closed:
#    1214             self._raise_closed()
# -> 1215         return io.open(self, mode, buffering, encoding, errors, newline,
#    1216                        opener=self._opener)
#    1217
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pathlib.py in _opener(self, name, flags, mode)
#    1069     def _opener(self, name, flags, mode=0o666):
#    1070         # A stub for the opener argument to built-in open()
# -> 1071         return self._accessor.open(self, flags, mode)
#    1072
#    1073     def _raw_open(self, flags, mode=0o777):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../test_exp/.ndi/documents/f182706005be4371b6833ea0f4f23e55.dat'

# %%
db.find_by_id(history[-1].id)
# Out:
# ------------------------------------------------------------------------
# FileNotFoundError                      Traceback (most recent call last)
# <ipython-input-17-6df42074165c> in <module>
# ----> 1 db.find_by_id(history[-1].id)
#
# ~/projects/ndi/ndi-python/ndi/database/file_system.py in find_by_id(self, id_)
#      78
#      79     def find_by_id(self, id_):
# ---> 80         doc = Document.from_flatbuffer((self.db_dir / f'{id_}.dat').read_bytes())
#      81         return doc.with_ctx(self)
#      82
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pathlib.py in read_bytes(self)
#    1220         Open the file in bytes mode, read it, and close the file.
#    1221         """
# -> 1222         with self.open(mode='rb') as f:
#    1223             return f.read()
#    1224
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1213         if self._closed:
#    1214             self._raise_closed()
# -> 1215         return io.open(self, mode, buffering, encoding, errors, newline,
#    1216                        opener=self._opener)
#    1217
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pathlib.py in _opener(self, name, flags, mode)
#    1069     def _opener(self, name, flags, mode=0o666):
#    1070         # A stub for the opener argument to built-in open()
# -> 1071         return self._accessor.open(self, flags, mode)
#    1072
#    1073     def _raw_open(self, flags, mode=0o777):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../test_exp/.ndi/documents/6aed0da1f5f8428583c5727e192bd2d8.dat'

# %%
# Out:
# ------------------------------------------------------------------------
# FileNotFoundError                      Traceback (most recent call last)
# <ipython-input-18-22e764cd9b97> in <module>
# ----> 1 doc.delete(force=True, remove_history=True)
#
# ~/projects/ndi/ndi-python/ndi/document.py in delete(self, force, remove_history)
#     145             ]
#     146             if remove_history:
# --> 147                 deletees.extend(self.get_history())
#     148             for ndi_document in deletees:
#     149                 self.ctx.delete(ndi_document)
#
# ~/projects/ndi/ndi-python/ndi/document.py in get_history(self)
#     136         """oldest to newest"""
#     137         ids = self.data['_metadata']['asc_path'].split(',')[1:]
# --> 138         return [self.ctx.find_by_id(id) for id in reversed(ids)]
#     139
#     140     def delete(self, force=False, remove_history=False,):
#
# ~/projects/ndi/ndi-python/ndi/document.py in <listcomp>(.0)
#     136         """oldest to newest"""
#     137         ids = self.data['_metadata']['asc_path'].split(',')[1:]
# --> 138         return [self.ctx.find_by_id(id) for id in reversed(ids)]
#     139
#     140     def delete(self, force=False, remove_history=False,):
#
# ~/projects/ndi/ndi-python/ndi/database/file_system.py in find_by_id(self, id_)
#      78
#      79     def find_by_id(self, id_):
# ---> 80         doc = Document.from_flatbuffer((self.db_dir / f'{id_}.dat').read_bytes())
#      81         return doc.with_ctx(self)
#      82
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pathlib.py in read_bytes(self)
#    1220         Open the file in bytes mode, read it, and close the file.
#    1221         """
# -> 1222         with self.open(mode='rb') as f:
#    1223             return f.read()
#    1224
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1213         if self._closed:
#    1214             self._raise_closed()
# -> 1215         return io.open(self, mode, buffering, encoding, errors, newline,
#    1216                        opener=self._opener)
#    1217
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pathlib.py in _opener(self, name, flags, mode)
#    1069     def _opener(self, name, flags, mode=0o666):
#    1070         # A stub for the opener argument to built-in open()
# -> 1071         return self._accessor.open(self, flags, mode)
#    1072
#    1073     def _raw_open(self, flags, mode=0o777):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../test_exp/.ndi/documents/58d0fefdb17440a9b0514cec915b772b.dat'
