# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Document, Query as Q
from ndi.database import FileSystem as Database

# %%
db = Database('../test_exp')

# %%
doc = Document({ 'subject': 'mouse' })
doc.id
# Out:
# '16b4174a46844ac3a11754b5e4bc9424'

# %%
doc.data['_metadata']
# Out:
# {'name': '',
#  'type': '',
#  'experiment_id': '',
#  'parent_id': '',
#  'asc_path': '',
#  'version_depth': 0,
#  'latest_version': True}

# %%
db.add(doc)

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'name': '', 'type': '', 'experiment_id': '', 'parent_id': '', 'asc_path': '', 'version_depth': 0, 'latest_version': True}, '_dependencies': {}, '_depends_on': [], 'subject': 'mouse'}

# %%
doc.data['subject'] = 'elephant'

# %%
doc.save_updates()

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'name': '', 'type': '', 'experiment_id': '', 'parent_id': '16b4174a46844ac3a11754b5e4bc9424', 'asc_path': ',16b4174a46844ac3a11754b5e4bc9424', 'version_depth': 1, 'latest_version': True}, '_dependencies': {}, '_depends_on': [], 'subject': 'elephant'}

# %%
doc.data['subject'] = 'elephants'
doc.save_updates()

# %%
doc.data
# Out:
# {'_metadata': {'name': '',
#   'type': '',
#   'experiment_id': '',
#   'parent_id': '9efeeba369cd4bb68ffa4c55c0aaadc1',
#   'asc_path': ',9efeeba369cd4bb68ffa4c55c0aaadc1,16b4174a46844ac3a11754b5e4bc9424',
#   'version_depth': 2,
#   'latest_version': True},
#  '_dependencies': {},
#  '_depends_on': [],
#  'subject': 'elephants'}

# %%
history = doc.get_history()
[d.data for d in history]
# Out:
# [{'_metadata': {'name': '',
#    'type': '',
#    'experiment_id': '',
#    'parent_id': '',
#    'asc_path': '',
#    'version_depth': 0,
#    'latest_version': False},
#   '_dependencies': {},
#   '_depends_on': [],
#   'subject': 'elephant'},
#  {'_metadata': {'name': '',
#    'type': '',
#    'experiment_id': '',
#    'parent_id': '16b4174a46844ac3a11754b5e4bc9424',
#    'asc_path': ',16b4174a46844ac3a11754b5e4bc9424',
#    'version_depth': 1,
#    'latest_version': False},
#   '_dependencies': {},
#   '_depends_on': [],
#   'subject': 'elephants'}]

# %%
# Should throw warning
# try:
#     doc.delete()
# except RuntimeWarning(e):
#     pass

# %%
doc.delete(force=True, remove_history=True)

# %%
db.find_by_id(doc.id)

# %%
db.find_by_id(history[-1].id)
