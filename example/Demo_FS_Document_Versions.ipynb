# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import Document
from ndi.database import FileSystem as Database, Query as Q

# %%
db = Database('../test_exp')

# %%
doc = Document({ 'subject': 'mouse' })
doc.id
# Out:
# '5af052a7c2be43b58050034d12da09d6'

# %%
doc.data['_metadata']
# Out:
# {'name': '',
#  'type': '',
#  'experiment_id': '',
#  'parent_id': '',
#  'asc_path': '',
#  'version_depth': 0}

# %%
db.add(doc)

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'name': '', 'type': '', 'experiment_id': '', 'parent_id': '', 'asc_path': '', 'version_depth': 0}, '_dependencies': {}, 'subject': 'mouse'}

# %%
doc.data['subject'] = 'elephant'

# %%
doc.save_updates()

# %%
result = db.find_by_id(doc.id)
print(result.data)
# Out:
# {'_metadata': {'name': '', 'type': '', 'experiment_id': '', 'parent_id': '5af052a7c2be43b58050034d12da09d6', 'asc_path': ',5af052a7c2be43b58050034d12da09d6', 'version_depth': 1}, '_dependencies': {}, 'subject': 'elephant'}

# %%
doc.data['subject'] = 'elephants'
doc.save_updates()

# %%
doc.data
# Out:
# {'_metadata': {'name': '',
#   'type': '',
#   'experiment_id': '',
#   'parent_id': '2d9fe10a3a07404cb56556c7440a614e',
#   'asc_path': ',2d9fe10a3a07404cb56556c7440a614e,5af052a7c2be43b58050034d12da09d6',
#   'version_depth': 2},
#  '_dependencies': {},
#  'subject': 'elephants'}
