# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import database
from ndi.database.types import Integer, String, Blob

# %%
# Connect to database
db = database.SQL('postgres://postgres:1Password!@localhost:5432/practice')

# %%
db.create_collections()
# Out:
# {'flatBuffer': Column(None, LargeBinary(), table=None)}
# {'id': Column(None, String(), table=None, primary_key=True, nullable=False)}
# 2020-01-20 20:17:24,528 INFO sqlalchemy.engine.base.Engine select version()
# 2020-01-20 20:17:24,529 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:17:24,531 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2020-01-20 20:17:24,532 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:17:24,534 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-01-20 20:17:24,535 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:17:24,537 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-01-20 20:17:24,538 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:17:24,540 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2020-01-20 20:17:24,541 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:17:24,544 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,545 INFO sqlalchemy.engine.base.Engine {'name': 'experiments'}
# 2020-01-20 20:17:24,548 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE experiments (
# 	"flatBuffer" BYTEA,
# 	id VARCHAR NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2020-01-20 20:17:24,549 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:17:24,554 INFO sqlalchemy.engine.base.Engine COMMIT
# {'experiment_id': Column(None, String(), ForeignKey('experiments.id'), table=None), 'flatBuffer': Column(None, LargeBinary(), table=None)}
# {'id': Column(None, String(), table=None, primary_key=True, nullable=False)}
# 2020-01-20 20:17:24,559 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,560 INFO sqlalchemy.engine.base.Engine {'name': 'experiments'}
# 2020-01-20 20:17:24,562 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,563 INFO sqlalchemy.engine.base.Engine {'name': 'daq_systems'}
# 2020-01-20 20:17:24,565 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE daq_systems (
# 	experiment_id VARCHAR,
# 	"flatBuffer" BYTEA,
# 	id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(experiment_id) REFERENCES experiments (id)
# )
#
#
# 2020-01-20 20:17:24,566 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:17:24,571 INFO sqlalchemy.engine.base.Engine COMMIT
# {'daq_system_id': Column(None, String(), ForeignKey('daq_systems.id'), table=None), 'flatBuffer': Column(None, LargeBinary(), table=None)}
# {'id': Column(None, String(), table=None, primary_key=True, nullable=False)}
# 2020-01-20 20:17:24,576 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,577 INFO sqlalchemy.engine.base.Engine {'name': 'experiments'}
# 2020-01-20 20:17:24,579 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,580 INFO sqlalchemy.engine.base.Engine {'name': 'daq_systems'}
# 2020-01-20 20:17:24,582 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,582 INFO sqlalchemy.engine.base.Engine {'name': 'epochs'}
# 2020-01-20 20:17:24,584 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE epochs (
# 	daq_system_id VARCHAR,
# 	"flatBuffer" BYTEA,
# 	id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(daq_system_id) REFERENCES daq_systems (id)
# )
#
#
# 2020-01-20 20:17:24,585 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:17:24,590 INFO sqlalchemy.engine.base.Engine COMMIT
# {'daq_system_id': Column(None, String(), ForeignKey('daq_systems.id'), table=None), 'flatBuffer': Column(None, LargeBinary(), table=None)}
# {'id': Column(None, String(), table=None, primary_key=True, nullable=False)}
# 2020-01-20 20:17:24,594 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,595 INFO sqlalchemy.engine.base.Engine {'name': 'experiments'}
# 2020-01-20 20:17:24,597 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,598 INFO sqlalchemy.engine.base.Engine {'name': 'daq_systems'}
# 2020-01-20 20:17:24,600 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,601 INFO sqlalchemy.engine.base.Engine {'name': 'epochs'}
# 2020-01-20 20:17:24,603 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,604 INFO sqlalchemy.engine.base.Engine {'name': 'probes'}
# 2020-01-20 20:17:24,606 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE probes (
# 	daq_system_id VARCHAR,
# 	"flatBuffer" BYTEA,
# 	id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(daq_system_id) REFERENCES daq_systems (id)
# )
#
#
# 2020-01-20 20:17:24,607 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:17:24,611 INFO sqlalchemy.engine.base.Engine COMMIT
# {'probe_id': Column(None, String(), ForeignKey('probes.id'), table=None), 'flatBuffer': Column(None, LargeBinary(), table=None)}
# {'id': Column(None, String(), table=None, primary_key=True, nullable=False)}
# 2020-01-20 20:17:24,615 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,616 INFO sqlalchemy.engine.base.Engine {'name': 'experiments'}
# 2020-01-20 20:17:24,618 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,619 INFO sqlalchemy.engine.base.Engine {'name': 'daq_systems'}
# 2020-01-20 20:17:24,621 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,622 INFO sqlalchemy.engine.base.Engine {'name': 'epochs'}
# 2020-01-20 20:17:24,624 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,625 INFO sqlalchemy.engine.base.Engine {'name': 'probes'}
# 2020-01-20 20:17:24,626 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,627 INFO sqlalchemy.engine.base.Engine {'name': 'channels'}
# 2020-01-20 20:17:24,629 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE channels (
# 	probe_id VARCHAR,
# 	"flatBuffer" BYTEA,
# 	id VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(probe_id) REFERENCES probes (id)
# )
#
#
# 2020-01-20 20:17:24,630 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:17:24,633 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-01-20 20:17:24,635 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,636 INFO sqlalchemy.engine.base.Engine {'name': 'experiments'}
# 2020-01-20 20:17:24,637 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,638 INFO sqlalchemy.engine.base.Engine {'name': 'daq_systems'}
# 2020-01-20 20:17:24,640 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,640 INFO sqlalchemy.engine.base.Engine {'name': 'epochs'}
# 2020-01-20 20:17:24,642 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,643 INFO sqlalchemy.engine.base.Engine {'name': 'probes'}
# 2020-01-20 20:17:24,644 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:17:24,645 INFO sqlalchemy.engine.base.Engine {'name': 'channels'}

# %%
print(db.tables)
# Out:
# {'experiments': <class 'ndi.database.sql.experiments'>, 'daq_systems': <class 'ndi.database.sql.daq_systems'>, 'epochs': <class 'ndi.database.sql.epochs'>, 'probes': <class 'ndi.database.sql.probes'>, 'channels': <class 'ndi.database.sql.channels'>}

# %%
# Create object using schema defined in table creation
example1 = Example(name='Tommy', age=144, data=b'hello')
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-1-a97821cb3b73> in <module>
#       1 # Create object using schema defined in table creation
# ----> 2 example1 = Example(name='Tommy', age=144, data=b'hello')
#
# NameError: name 'Example' is not defined

# %%
# Add object to database
db.add(example1)

# %%
# Search table in database based on query
results = db.find(Example, name='Tommy')
for result in results:
    print(result.id)
    print(result.name)
    print(result.age)
    print(result.data)

# %%
results = db.find(Example, age=144)
for result in results:
    print(result.id)
    print(result.name)
    print(result.age)
    print(result.data)
