# %%
# This adds the path to import the development version (git repo) of NDI Python
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ndi import database
from ndi.database.types import Integer, String, Blob

# %%
# Connect to database
db = database.SQL('postgres://postgres:1Password!@localhost:5432/practice')

# %%
# Create table in database
Example = db.create_table('examples', {
    'name': String,
    'age': Integer,
    'data': Blob
})
# Out:
# 2020-01-20 20:40:52,114 INFO sqlalchemy.engine.base.Engine select version()
# 2020-01-20 20:40:52,115 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:40:52,117 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2020-01-20 20:40:52,118 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:40:52,120 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-01-20 20:40:52,121 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:40:52,123 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-01-20 20:40:52,124 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:40:52,125 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2020-01-20 20:40:52,126 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:40:52,128 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-01-20 20:40:52,129 INFO sqlalchemy.engine.base.Engine {'name': 'examples'}
# 2020-01-20 20:40:52,131 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE examples (
# 	id VARCHAR NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2020-01-20 20:40:52,132 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:40:52,137 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# Create object using schema defined in table creation
example1 = Example(name='Tommy', age=144, data=b'hello')

# %%
# Add object to database
db.add(example1)
# Out:
# 2020-01-20 20:40:56,798 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-01-20 20:40:56,800 INFO sqlalchemy.engine.base.Engine INSERT INTO examples DEFAULT VALUES
# 2020-01-20 20:40:56,801 INFO sqlalchemy.engine.base.Engine {}
# 2020-01-20 20:40:56,803 INFO sqlalchemy.engine.base.Engine ROLLBACK
# /Users/david/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/sql/crud.py:799: SAWarning: Column 'examples.id' is marked as a member of the primary key for table 'examples', but has no Python-side or server-side default generator indicated, nor does it indicate 'autoincrement=True' or 'nullable=True', and no explicit value is passed.  Primary key columns typically may not store NULL.
#   util.warn(msg)
# ------------------------------------------------------------------------
# NotNullViolation                       Traceback (most recent call last)
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     580     def do_execute(self, cursor, statement, parameters, context=None):
# --> 581         cursor.execute(statement, parameters)
#     582
#
# NotNullViolation: null value in column "id" violates not-null constraint
# DETAIL:  Failing row contains (null).
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                         Traceback (most recent call last)
# <ipython-input-8-851a9f08b686> in <module>
#       1 # Add object to database
# ----> 2 db.add(example1)
#
# ~/projects/ndi/ndi-python/ndi/database/sql.py in add(self, item)
#      60         session = self.Session()
#      61         session.add(item)
# ---> 62         self.__finish_session(session)
#      63
#      64     def find(self, Table, **kwargs):
#
# ~/projects/ndi/ndi-python/ndi/database/sql.py in __finish_session(self, session)
#      54
#      55     def __finish_session(self, session):
# ---> 56         session.commit()
#      57         session.close()
#      58
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/orm/session.py in commit(self)
#    1025                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#    1026
# -> 1027         self.transaction.commit()
#    1028
#    1029     def prepare(self):
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/orm/session.py in commit(self)
#     492         self._assert_active(prepared_ok=True)
#     493         if self._state is not PREPARED:
# --> 494             self._prepare_impl()
#     495
#     496         if self._parent is None or self.nested:
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/orm/session.py in _prepare_impl(self)
#     471                 if self.session._is_clean():
#     472                     break
# --> 473                 self.session.flush()
#     474             else:
#     475                 raise exc.FlushError(
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/orm/session.py in flush(self, objects)
#    2468         try:
#    2469             self._flushing = True
# -> 2470             self._flush(objects)
#    2471         finally:
#    2472             self._flushing = False
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/orm/session.py in _flush(self, objects)
#    2606         except:
#    2607             with util.safe_reraise():
# -> 2608                 transaction.rollback(_capture_exception=True)
#    2609
#    2610     def bulk_save_objects(
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/orm/session.py in _flush(self, objects)
#    2566             self._warn_on_events = True
#    2567             try:
# -> 2568                 flush_context.execute()
#    2569             finally:
#    2570                 self._warn_on_events = False
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/orm/unitofwork.py in execute(self)
#     420         else:
#     421             for rec in topological.sort(self.dependencies, postsort_actions):
# --> 422                 rec.execute(self)
#     423
#     424     def finalize_flush_changes(self):
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/orm/unitofwork.py in execute(self, uow)
#     587             self.mapper,
#     588             uow.states_for_mapper_hierarchy(self.mapper, False, False),
# --> 589             uow,
#     590         )
#     591
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/orm/persistence.py in save_obj(base_mapper, states, uowtransaction, single)
#     243             mapper,
#     244             table,
# --> 245             insert,
#     246         )
#     247
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/orm/persistence.py in _emit_insert_statements(base_mapper, uowtransaction, cached_connections, mapper, table, insert, bookkeeping)
#    1135                 else:
#    1136                     result = cached_connections[connection].execute(
# -> 1137                         statement, params
#    1138                     )
#    1139
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     980             raise exc.ObjectNotExecutableError(object_)
#     981         else:
# --> 982             return meth(self, multiparams, params)
#     983
#     984     def _execute_function(self, func, multiparams, params):
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1099             distilled_params,
#    1100             compiled_sql,
# -> 1101             distilled_params,
#    1102         )
#    1103         if self._has_events or self.engine._has_events:
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1474                 util.raise_from_cause(newraise, exc_info)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#    1478                 util.reraise(*exc_info)
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1244                 if not evt_handled:
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#    1248         except BaseException as e:
#
# ~/.local/share/virtualenvs/ndi-python-563Qsmkf/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     579
#     580     def do_execute(self, cursor, statement, parameters, context=None):
# --> 581         cursor.execute(statement, parameters)
#     582
#     583     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.errors.NotNullViolation) null value in column "id" violates not-null constraint
# DETAIL:  Failing row contains (null).
#
# [SQL: INSERT INTO examples DEFAULT VALUES]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
# Search table in database based on query
results = db.find(Example, name='Tommy')
for result in results:
    print(result.id)
    print(result.name)
    print(result.age)
    print(result.data)
# Out:
# 2
# Tommy
# 144
# b'hello'
# 3
# Tommy
# 144
# b'hello'
# 4
# Tommy
# 144
# b'hello'

# %%
results = db.find(Example, age=144)
for result in results:
    print(result.id)
    print(result.name)
    print(result.age)
    print(result.data)
# Out:
# 2
# Tommy
# 144
# b'hello'
# 3
# Tommy
# 144
# b'hello'
# 4
# Tommy
# 144
# b'hello'
